# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('CarPrice_Assignment.csv')

# %%
raw_data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
raw_data['CarName'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object>

# %% [markdown]
# ###  Preprocessing

# %%
raw_data.describe(include = 'all')
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber  \
# count   205.000000  205.000000            205      205        205        205
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
# ...

# %%
x = raw_data['price'].values.reshape(-1,1)
y = raw_data['enginesize'].values

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.figure(figsize = (12,8))
plt.title('Predection Test', fontsize=18)
plt.xlabel('price', fontsize=18)
plt.ylabel('enginesize', fontsize=18)
plt.scatter(x,y)
plt.plot(x,y_pred,c='r')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE = mean_squared_error(y,y_pred)
MAE = mean_absolute_error(y,y_pred)
print('mean_squared_error', MSE)
print('mean_absolute_error', MAE)
# Out:
# mean_squared_error 407.03169480133647
# mean_absolute_error 14.220776046721225

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)
Pl_model = LinearRegression()
Pl_model.fit(x_poly,y)
yy_pred = Pl_model.predict(x_poly)
plt.scatter(x,y)
plt.plot(x,yy_pred,c='g')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE = mean_squared_error(y,yy_pred)
MAE = mean_absolute_error(y,yy_pred)
print('mean_squared_error', MSE)
print('mean_absolute_error', MAE)
# Out:
# mean_squared_error 390.2159572998511
# mean_absolute_error 13.707531093643984

# %%
log_price = np.log(raw_data['price'])
raw_data['log_price'] = log_price
raw_data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...
